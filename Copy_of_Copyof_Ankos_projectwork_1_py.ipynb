# %% [markdown]
# <a href="https://colab.research.google.com/github/ankomarvin/Ankos-repository-/blob/main/Copy_of_Copyof_Ankos_projectwork_1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_name ='Marvin Elvis. Mbidde'
print(my_name)
age =19 #not a lie
print(age)
print(f'lets talk abt {age}')
print("doesn't")
print('doesn\'t')
mixednumber =5+90.8
print(type(mixednumber))
addstring= 'fish'+ 'balls'
print(addstring)
addstring= 'river'+ 'bank'
print(addstring)
print(addstring,addstring)
mixednumbers= 1 +2 *3 /4.0
print(mixednumbers)
remainder=11 %3
print(remainder)
my_name ='Ntege Zuena'
print(my_name)
age= 19 #true
print(age)
# Out:
# Marvin Elvis. Mbidde
# 19
# lets talk abt 19
# doesn't
# doesn't
# <class 'float'>
# fishballs
# riverbank
# riverbank riverbank
# 2.5
# 2

# %%
my_name ='Ntege Zuena'
age= 19
print(f'lets talk abt {age}')
print(my_name)
print(age)
my_name = 'Bulamu F. Mariam'
age= 19
print(my_name)
print (f'lets talk abt {age}')

from datetime import date

# Ask user for birth date
birth_year = int(input("Enter your birth year (YYYY): "))
birth_month = int(input("Enter your birth month (MM): "))
birth_day = int(input("Enter your birth day (DD): "))

# Get today's date
today = date.today()

# Calculate age
age = today.year - birth_year

# Adjust if birthday hasn't happened yet this year
if (today.month, today.day) < (birth_month, birth_day):
    age -= 1

print("You are", age, "years old.")
birth_year = 2006
birth_month = 9
birth_day = 21
today = date.today
age =today.year - birth_year
print(age)
# Out:
# lets talk abt 19
# Ntege Zuena
# 19
# Bulamu F. Mariam
# lets talk abt 19
